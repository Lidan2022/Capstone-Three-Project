# %% [markdown]
# # Capstone Three Project :  Alcohol Sale Forecasting

# %% [raw]
# Recap Of This Data Science Project:
# This project is going to use time series model to forecat the alcohol sale.

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_predict
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Loading the data

# %% [raw]
# Data Source:
# https://www.kaggle.com/datasets/bulentsiyah/for-simple-exercises-time-series-forecasting?select=Alcohol_Sales.csv

# %%
# import data
Alcohol = pd.read_csv('Alcohol_Sales.csv')

# %% [markdown]
# # 3. Data Wrangling

# %% [raw]
# Data wrangling is the process of converting raw data into a usable form.
# It may also be called data munging or data remediation.

# %%
# check the first 5 rows
Alcohol.head()
# Out:
#          DATE  S4248SM144NCEN
# 0  1992-01-01            3459
# 1  1992-02-01            3458
# 2  1992-03-01            4002
# 3  1992-04-01            4564
# 4  1992-05-01            4221

# %%
# check the last five rows
Alcohol.tail()
# Out:
#            DATE  S4248SM144NCEN
# 320  2018-09-01           12396
# 321  2018-10-01           13914
# 322  2018-11-01           14174
# 323  2018-12-01           15504
# 324  2019-01-01           10718

# %%
# describe the data in statistic form
Alcohol.describe()
# Out:
#        S4248SM144NCEN
# count      325.000000
# mean      7886.400000
# std       2914.269061
# min       3031.000000
# 25%       5231.000000
# 50%       7481.000000
# 75%       9977.000000
# max      15504.000000

# %%
# check the name of the columns
Alcohol.columns
# Out:
# Index(['DATE', 'S4248SM144NCEN'], dtype='object')

# %%
# change the columns name to make it more readable
Alcohol.rename(columns={'DATE':'date', 'S4248SM144NCEN':'sold'}, inplace=True)
Alcohol.head()
# Out:
#          date  sold
# 0  1992-01-01  3459
# 1  1992-02-01  3458
# 2  1992-03-01  4002
# 3  1992-04-01  4564
# 4  1992-05-01  4221

# %%
# check if there are any missing values
Alcohol.isnull().sum()
# Out:
# date    0
# sold    0
# dtype: int64

# %%
# check if there are any duplicated data
Alcohol.duplicated().any()
# Out:
# False

# %%
# check the shape of the data
Alcohol.shape
# Out:
# (325, 2)

# %%
# check the general data information
Alcohol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    325 non-null    object
#  1   sold    325 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.2+ KB

# %%
# sort the values by 'date'
Alcohol.sort_values(by='date')
Alcohol.head(20)
# Out:
#           date  sold
# 0   1992-01-01  3459
# 1   1992-02-01  3458
# 2   1992-03-01  4002
# 3   1992-04-01  4564
# 4   1992-05-01  4221
# 5   1992-06-01  4529
# 6   1992-07-01  4466
# 7   1992-08-01  4137
# 8   1992-09-01  4126
# 9   1992-10-01  4259
# 10  1992-11-01  4240
# 11  1992-12-01  4936
# 12  1993-01-01  3031
# 13  1993-02-01  3261
# 14  1993-03-01  4160
# 15  1993-04-01  4377
# 16  1993-05-01  4307
# 17  1993-06-01  4696
# 18  1993-07-01  4458
# 19  1993-08-01  4457

# %%
# check the data types
Alcohol.dtypes
# Out:
# date    object
# sold     int64
# dtype: object

# %%
# change the 'date' column to datetime frame
Alcohol['date']=pd.to_datetime(Alcohol['date'])

# %%
# check the data types again
Alcohol.dtypes
# Out:
# date    datetime64[ns]
# sold             int64
# dtype: object

# %%
# set the 'date' column to index
Alcohol=Alcohol.set_index('date')
Alcohol.head()
# Out:
#             sold
# date
# 1992-01-01  3459
# 1992-02-01  3458
# 1992-03-01  4002
# 1992-04-01  4564
# 1992-05-01  4221

# %%
Alcohol.tail()
# Out:
#              sold
# date
# 2018-09-01  12396
# 2018-10-01  13914
# 2018-11-01  14174
# 2018-12-01  15504
# 2019-01-01  10718

# %% [markdown]
# # 4. Exploratory Data Analysis And Visualization

# %% [raw]
# EDA is an approach to analyzing the data using visual techniques. It is used to discover trends, and patterns, or to check assumptions with the help of statistical summaries and graphical representations.

# %%
# visualize the data
Alcohol.plot()
# Out:
# <Axes: xlabel='date'>

# %% [raw]
# aWe can clearly see a upward trend in Alcohol sales. There are also some seasonality here.

# %% [raw]
# In our plot, we can see that both the mean and the variance increase as time progresses. At the moment, our data has neither a constant mean, nor a constant variance (the covariance, however, seems constant).

# %% [raw]
# Let’s now plot the ACF and PACF of our data set time series.

# %%
# Plot the ACF and PACF on the same page
fig, axes = plt.subplots(2,1)
plot_acf(Alcohol, lags=20, ax=axes[0])
plot_pacf(Alcohol, lags=20, ax=axes[1])
plt.show()

# %% [raw]
# The ACF plot shows the correlations with the lags are high and positive with very slow decay. While the PACF plot shows the partial autocorrelations has a strong spikes at lag 1. These are both signs of a trended time series. So our time series is not stationary.

# %% [raw]
# We will also quantify the value to check.

# %%
# test data stationary
kpss(Alcohol)
# Out:
# (2.794429681699147,
#  0.01,
#  11,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [raw]
# Since the p value is 0.01, which is less than 0.05. We can say our data is non stationary. We need to do some transformation to make our data stationary.

# %%
# use adfuller to test the stationary
adfuller(Alcohol['sold'])[1]
# Out:
# 0.9987196267088919

# %% [raw]
# Here p value is greater than 0.05. This can also tell the data is non stationary

# %% [markdown]
# # 5. Preprocessing Data

# %% [raw]
# We can now use the decompose() function to quantify the component parts in our data. First, we break data into three components, then adding them in an additive model.

# %%
# decompose the datase
decomposition = seasonal_decompose(Alcohol, model='additive')
fig = decomposition.plot()
plt.show()

# %% [raw]
# In our plot, we can see that both the mean and the variance increase as time progresses. At the moment, our data has neither a constant mean, nor a constant variance (the covariance, however, seems constant). One ofte used way of getting rid of changing variance is to take the natural log of all the values in our dataset.

# %%
log=np.log(Alcohol)

# %%
log.plot()
# Out:
# <Axes: xlabel='date'>

# %% [raw]
# When we plot this, we can see how the variance in our data now remains contant over time. We now have a constant variance, but we also need a constant mean. We can do this by differencing our data. We difference a time series dataset when we create a new time series comprising the difference between the values of our existing dataset. This will help to stabilize the mean of the time series by removing changes in the levels of the series

# %%
# Declare a variable using the differences of the log values
diff=log.diff().dropna()

# %%
# Visualize the transformed data values
diff.plot()
# Out:
# <Axes: xlabel='date'>

# %% [raw]
# You can see that the first difference time series doesn’t show a strong trend anymore. It looks to be more stationary.

# %% [raw]
# Let's test it again

# %%
# Test the stationary again
kpss(diff)
# Out:
# (0.0869598088182859,
#  0.1,
#  19,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [raw]
# The p-value is greater than 0.05. So we can conclude that our first difference time series is likely to be stationary.

# %% [markdown]
# # 6. Modelling

# %% [raw]
# Now we start to build our model. Before we fit our model. we need to find the best parameters. Let's take a look at the ACF and PACF.

# %%
# Visualize the autocorrelation and partial autocorrelation after transforming the data
fig, axes = plt.subplots(2,1)
plot_acf(diff, lags=20, ax=axes[0])
plot_pacf(diff, lags=20, ax=axes[1])
plt.show()

# %% [raw]
# The ACF and PACF were a little inconclusive. We will search over some model orders to find the best one according to AIC.

# %%
from pmdarima.arima import auto_arima
model = auto_arima(Alcohol, trace=True, error_action='ignore', suppress_warnings=True)
model.fit(diff)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5581.852, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5521.140, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5399.757, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5579.946, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5400.180, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5399.909, Time=0.26 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5427.084, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 1.676 seconds
# ARIMA(order=(0, 1, 1), scoring_args={}, suppress_warnings=True)

# %%
mod1 = ARIMA(Alcohol, order=(0,1,1))
res1 = mod1.fit()
res1.plot_diagnostics()
plt.show()

# %%
print(res1.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                   sold   No. Observations:                  325
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -2711.542
# Date:                Sat, 17 Jun 2023   AIC                           5427.084
# Time:                        14:15:49   BIC                           5434.645
# Sample:                    01-01-1992   HQIC                          5430.102
#                          - 01-01-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8644      0.022    -39.968      0.000      -0.907      -0.822
# sigma2      1.077e+06   8.03e+04     13.415      0.000     9.2e+05    1.23e+06
# ...
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                58.01
# ...

# %%
# Calculate the mean absolute error from residuals
mae = np.mean(np.abs(res1.resid))
# Print mean absolute error
print(mae)
# Out:
# 804.847670921366

# %%
fig, ax = plt.subplots()
Alcohol.plot(ax=ax)
plot_predict(res1, start='1994', end='2029', alpha=0.05, ax=ax)
plt.show()
